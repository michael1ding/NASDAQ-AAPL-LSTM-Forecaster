# %% [markdown]
# ## TSLA LSTM Deep-Learning Predictor

# %% [markdown]
# We will be using stock market ticker data from Kaggle (https://www.kaggle.com/borismarjanovic/price-volume-data-for-all-us-stocks-etfs) and using a LSTM stateful model.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current sessionimport numpy as np
import matplotlib.pyplot as plt
import pandas as pdb
# Out:
# /kaggle/input/tsla-train/TSLA.csv
# /kaggle/input/tsla-stock/tsla.us.csv
# /kaggle/input/actual-test/TSLA (2).csv
# /kaggle/input/test-tsla/TSLA (1).csv
# /kaggle/input/aapl-test/AAPL (2).csv
# /kaggle/input/aapl-train/AAPL (1).csv
# /kaggle/input/tsla-test/TSLA.csv

# %%
import types
import pandas as pd
import os

df_data_1 = pd.read_csv('../input/aapl-train/AAPL (1).csv')
df_data_1.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close      Volume
# 0  2010-06-29  9.432858  9.442500  9.082143  9.148929   7.892332  1133344800
# 1  2010-06-30  9.168214  9.213214  8.928928  8.983214   7.749377   739452000
# 2  2010-07-01  9.082143  9.100000  8.686429  8.874286   7.655411  1022896000
# 3  2010-07-02  8.946072  8.961785  8.685715  8.819285   7.607966   693842800
# 4  2010-07-06  8.964286  9.028571  8.791429  8.879642   7.660032   615235600

# %% [markdown]
# **Do Data exploration by making correlation matrix**

# %%
df_data_1.corr(method="pearson")
# Out:
#                Open      High       Low     Close  Adj Close    Volume
# Open       1.000000  0.999726  0.999660  0.999378   0.997699 -0.605814
# High       0.999726  1.000000  0.999589  0.999714   0.997960 -0.602309
# Low        0.999660  0.999589  1.000000  0.999731   0.998244 -0.613146
# Close      0.999378  0.999714  0.999731  1.000000   0.998391 -0.608270
# Adj Close  0.997699  0.997960  0.998244  0.998391   1.000000 -0.621793
# Volume    -0.605814 -0.602309 -0.613146 -0.608270  -0.621793  1.000000

# %% [markdown]
# **So we see that Open price is loosely correlated with factors like volume. Now, let's do some data visualization**

# %%
df_data_1.plot(x="Date", y=["Open"])

# %% [markdown]
# **Now, we check for any null values when doing data cleansing. Remove the first day of TSLA IPO as volume was 0.**

# %%
df_data_1.isnull().values.any()
# Out:
# False

# %%
df_data_1 = df_data_1.iloc[1:]
df_data_1.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close      Volume
# 1  2010-06-30  9.168214  9.213214  8.928928  8.983214   7.749377   739452000
# 2  2010-07-01  9.082143  9.100000  8.686429  8.874286   7.655411  1022896000
# 3  2010-07-02  8.946072  8.961785  8.685715  8.819285   7.607966   693842800
# 4  2010-07-06  8.964286  9.028571  8.791429  8.879642   7.660032   615235600
# 5  2010-07-07  8.946072  9.241786  8.919642  9.238214   7.969353   654556000

# %% [markdown]
# **We are really only interested in date, open, high-low(volatility), and volume for our analysis.**

# %%
df_data_1["High-Low"]=df_data_1["High"] - df_data_1["Low"]
df_data_1.head()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#          Date      Open      High       Low     Close  Adj Close      Volume  \
# 1  2010-06-30  9.168214  9.213214  8.928928  8.983214   7.749377   739452000
# 2  2010-07-01  9.082143  9.100000  8.686429  8.874286   7.655411  1022896000
# 3  2010-07-02  8.946072  8.961785  8.685715  8.819285   7.607966   693842800
# 4  2010-07-06  8.964286  9.028571  8.791429  8.879642   7.660032   615235600
# 5  2010-07-07  8.946072  9.241786  8.919642  9.238214   7.969353   654556000
#
#    High-Low
# 1  0.284286
# 2  0.413571
# 3  0.276070
# 4  0.237142
# 5  0.322144

# %%
df_tsla = df_data_1[['Open']]
df_tsla.head()
# Out:
#        Open
# 1  9.168214
# 2  9.082143
# 3  8.946072
# 4  8.964286
# 5  8.946072

# %%
len(df_tsla)
# Out:
# 1855

# %% [markdown]
# **Let's do some data normalization**

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range = (0, 1))

df = scaler.fit_transform(df_tsla)

# %%
df[:10]
# Out:
# array([[0.01896238],
#        [0.01651465],
#        [0.01264499],
#        [0.01316297],
#        [0.01264499],
#        [0.02482276],
#        [0.01914521],
#        [0.02081088],
#        [0.01856626],
#        [0.01151757]])

# %% [markdown]
# **Now, we do feature engineering, using past 60 days as feature set and we predict the label on the next day. Also create a second and third set for comparison purposes (30, 45) days.**

# %%
features_set = []
labels = []
timesteps = 60
for i in range(timesteps, 1855):
    features_set.append(df[i-timesteps:i, 0])
    labels.append(df[i, 0])

# %%
features_set, labels = np.array(features_set), np.array(labels)

# %%
features_set = np.reshape(features_set, (features_set.shape[0], features_set.shape[1], 1))

# %%
labels.shape
# Out:
# (1795,)

# %%
labels[:10]
# Out:
# array([0.05490665, 0.0568161 , 0.05457148, 0.04996037, 0.05175808,
#        0.04886347, 0.04424221, 0.04464845, 0.05235734, 0.05311909])

# %%
features_set.shape
# Out:
# (1795, 60, 1)

# %%
features_set_45 = []
labels_45 = []
timesteps = 45
for i in range(timesteps, 1855):
    features_set_45.append(df[i-timesteps:i, 0])
    labels_45.append(df[i, 0])
    
features_set_45, labels_45 = np.array(features_set_45), np.array(labels_45)
features_set_45 = np.reshape(features_set_45, (features_set_45.shape[0], features_set_45.shape[1], 1))

# %%
features_set_70 = []
labels_70 = []
timesteps = 70
for i in range(timesteps, 1855):
    features_set_70.append(df[i-timesteps:i, 0])
    labels_70.append(df[i, 0])
    
features_set_70, labels_70 = np.array(features_set_70), np.array(labels_70)
features_set_70 = np.reshape(features_set_70, (features_set_70.shape[0], features_set_70.shape[1], 1))

# %% [markdown]
# **Develop and Train the LSTM**

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from sklearn.metrics import mean_squared_error
import tensorflow as tf

# %%
model = Sequential()
model.add(LSTM(units=100, return_sequences=True, input_shape=(features_set.shape[1], 1)))
model.add(Dropout(0.2))
model.add(LSTM(units=100, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=200, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=400, return_sequences=True))
model.add(Dropout(0.25))
model.add(LSTM(units=400, return_sequences=True))
model.add(Dropout(0.25))
model.add(LSTM(units=200, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=100, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50))
model.add(Dropout(0.2))
model.add(Dense(units = 1))

# %%
model.compile(optimizer = 'adamax', loss = 'mae', metrics = [tf.keras.metrics.MeanAbsolutePercentageError()])

# %%
model.fit(features_set, labels, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.1094 - mean_absolute_percentage_error: 34.4989
# Epoch 2/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0567 - mean_absolute_percentage_error: 15.2782
# Epoch 3/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0526 - mean_absolute_percentage_error: 14.1060
# Epoch 4/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0496 - mean_absolute_percentage_error: 13.2436
# Epoch 5/100
# 57/57 [==============================] - 2s 43ms/step - loss: 0.0524 - mean_absolute_percentage_error: 14.0213
# Epoch 6/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0498 - mean_absolute_percentage_error: 13.5249
# Epoch 7/100
# 57/57 [==============================] - 2s 42ms/step - loss: 0.0538 - mean_absolute_percentage_error: 14.2120
# Epoch 8/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0478 - mean_absolute_percentage_error: 12.8404
# Epoch 9/100
# 57/57 [==============================] - 2s 41ms/step - loss: 0.0485 - mean_absolute_percentage_error: 13.4349
# Epoch 10/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0433 - mean_absolute_percentage_error: 12.0343
# Epoch 11/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0447 - mean_absolute_percentage_error: 12.2690
# Epoch 12/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0408 - mean_absolute_percentage_error: 11.5796
# Epoch 13/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0406 - mean_absolute_percentage_error: 11.5480
# Epoch 14/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0454 - mean_absolute_percentage_error: 13.1422
# Epoch 15/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0412 - mean_absolute_percentage_error: 11.4303
# Epoch 16/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0427 - mean_absolute_percentage_error: 12.2222
# Epoch 17/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0383 - mean_absolute_percentage_error: 10.8639
# Epoch 18/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0401 - mean_absolute_percentage_error: 11.0113
# Epoch 19/100
# 57/57 [==============================] - 2s 41ms/step - loss: 0.0391 - mean_absolute_percentage_error: 11.2428
# Epoch 20/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0401 - mean_absolute_percentage_error: 11.3576
# Epoch 21/100
# 57/57 [==============================] - 2s 41ms/step - loss: 0.0375 - mean_absolute_percentage_error: 10.5634
# Epoch 22/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0376 - mean_absolute_percentage_error: 10.4689
# Epoch 23/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0387 - mean_absolute_percentage_error: 11.3901
# Epoch 24/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0371 - mean_absolute_percentage_error: 11.1655
# Epoch 25/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0380 - mean_absolute_percentage_error: 11.2460
# Epoch 26/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0401 - mean_absolute_percentage_error: 11.1771
# Epoch 27/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0365 - mean_absolute_percentage_error: 10.1728
# Epoch 28/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0356 - mean_absolute_percentage_error: 10.3414
# Epoch 29/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0355 - mean_absolute_percentage_error: 10.2759
# Epoch 30/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0373 - mean_absolute_percentage_error: 11.4944
# Epoch 31/100
# 57/57 [==============================] - 2s 43ms/step - loss: 0.0355 - mean_absolute_percentage_error: 10.3916
# Epoch 32/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0335 - mean_absolute_percentage_error: 9.8580
# Epoch 33/100
# 57/57 [==============================] - 3s 46ms/step - loss: 0.0350 - mean_absolute_percentage_error: 9.9594
# Epoch 34/100
# 57/57 [==============================] - 2s 41ms/step - loss: 0.0365 - mean_absolute_percentage_error: 10.9120
# Epoch 35/100
# 57/57 [==============================] - 2s 42ms/step - loss: 0.0352 - mean_absolute_percentage_error: 10.2122
# Epoch 36/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0381 - mean_absolute_percentage_error: 10.6767
# Epoch 37/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0349 - mean_absolute_percentage_error: 10.2691
# Epoch 38/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0362 - mean_absolute_percentage_error: 10.2584
# Epoch 39/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0328 - mean_absolute_percentage_error: 9.6086
# Epoch 40/100
# 57/57 [==============================] - 2s 39ms/step - loss: 0.0315 - mean_absolute_percentage_error: 9.0348
# Epoch 41/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0333 - mean_absolute_percentage_error: 9.7940
# Epoch 42/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0329 - mean_absolute_percentage_error: 9.2541
# Epoch 43/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0318 - mean_absolute_percentage_error: 9.5105
# Epoch 44/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0312 - mean_absolute_percentage_error: 9.2827
# Epoch 45/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0308 - mean_absolute_percentage_error: 9.3500
# Epoch 46/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0330 - mean_absolute_percentage_error: 9.9268
# Epoch 47/100
# 57/57 [==============================] - 2s 41ms/step - loss: 0.0311 - mean_absolute_percentage_error: 9.1168
# Epoch 48/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0323 - mean_absolute_percentage_error: 9.1553
# Epoch 49/100
# 57/57 [==============================] - 2s 41ms/step - loss: 0.0327 - mean_absolute_percentage_error: 9.4872
# Epoch 50/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0306 - mean_absolute_percentage_error: 9.1689
# Epoch 51/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0318 - mean_absolute_percentage_error: 9.3111
# Epoch 52/100
# 57/57 [==============================] - 2s 41ms/step - loss: 0.0308 - mean_absolute_percentage_error: 8.7151
# Epoch 53/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0324 - mean_absolute_percentage_error: 9.4507
# Epoch 54/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0287 - mean_absolute_percentage_error: 8.4320
# Epoch 55/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0318 - mean_absolute_percentage_error: 9.6493
# Epoch 56/100
# 57/57 [==============================] - 2s 41ms/step - loss: 0.0318 - mean_absolute_percentage_error: 9.8734
# Epoch 57/100
# 57/57 [==============================] - 2s 43ms/step - loss: 0.0302 - mean_absolute_percentage_error: 8.7202
# Epoch 58/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0319 - mean_absolute_percentage_error: 10.3297
# Epoch 59/100
# 57/57 [==============================] - 2s 41ms/step - loss: 0.0323 - mean_absolute_percentage_error: 9.4009
# Epoch 60/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0306 - mean_absolute_percentage_error: 8.7646
# Epoch 61/100
# 57/57 [==============================] - 2s 41ms/step - loss: 0.0301 - mean_absolute_percentage_error: 9.6314
# Epoch 62/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0298 - mean_absolute_percentage_error: 9.1756
# Epoch 63/100
# 57/57 [==============================] - 2s 41ms/step - loss: 0.0299 - mean_absolute_percentage_error: 9.3729
# Epoch 64/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0295 - mean_absolute_percentage_error: 8.7928
# Epoch 65/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0297 - mean_absolute_percentage_error: 8.7421
# Epoch 66/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0293 - mean_absolute_percentage_error: 8.9667
# Epoch 67/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0285 - mean_absolute_percentage_error: 8.2172
# Epoch 68/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0290 - mean_absolute_percentage_error: 8.3477
# Epoch 69/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0282 - mean_absolute_percentage_error: 8.2961
# Epoch 70/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0288 - mean_absolute_percentage_error: 8.8272
# Epoch 71/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0298 - mean_absolute_percentage_error: 8.8311
# Epoch 72/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0277 - mean_absolute_percentage_error: 8.1761
# Epoch 73/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0263 - mean_absolute_percentage_error: 8.0540
# Epoch 74/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0278 - mean_absolute_percentage_error: 7.7794
# Epoch 75/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0272 - mean_absolute_percentage_error: 8.0279
# Epoch 76/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0269 - mean_absolute_percentage_error: 7.9914
# Epoch 77/100
# 57/57 [==============================] - 2s 41ms/step - loss: 0.0264 - mean_absolute_percentage_error: 7.5616
# Epoch 78/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0270 - mean_absolute_percentage_error: 8.0526
# Epoch 79/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0280 - mean_absolute_percentage_error: 8.1502
# Epoch 80/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0272 - mean_absolute_percentage_error: 8.5290
# Epoch 81/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0269 - mean_absolute_percentage_error: 8.0730
# Epoch 82/100
# 57/57 [==============================] - 2s 42ms/step - loss: 0.0272 - mean_absolute_percentage_error: 7.9959
# Epoch 83/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0276 - mean_absolute_percentage_error: 8.4177
# Epoch 84/100
# 57/57 [==============================] - 2s 41ms/step - loss: 0.0278 - mean_absolute_percentage_error: 8.4166
# Epoch 85/100
# 57/57 [==============================] - 2s 43ms/step - loss: 0.0253 - mean_absolute_percentage_error: 7.6637
# Epoch 86/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0261 - mean_absolute_percentage_error: 8.1304
# Epoch 87/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0256 - mean_absolute_percentage_error: 7.8616
# Epoch 88/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0254 - mean_absolute_percentage_error: 7.5412
# Epoch 89/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0261 - mean_absolute_percentage_error: 7.6348
# Epoch 90/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0245 - mean_absolute_percentage_error: 7.4565
# Epoch 91/100
# 57/57 [==============================] - 2s 41ms/step - loss: 0.0258 - mean_absolute_percentage_error: 7.3992
# Epoch 92/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0246 - mean_absolute_percentage_error: 7.6762
# Epoch 93/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0262 - mean_absolute_percentage_error: 8.2206
# Epoch 94/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0248 - mean_absolute_percentage_error: 7.5185
# Epoch 95/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0243 - mean_absolute_percentage_error: 7.5238
# Epoch 96/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0251 - mean_absolute_percentage_error: 7.4887
# Epoch 97/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0249 - mean_absolute_percentage_error: 7.6112
# Epoch 98/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0247 - mean_absolute_percentage_error: 7.4795
# Epoch 99/100
# 57/57 [==============================] - 2s 41ms/step - loss: 0.0259 - mean_absolute_percentage_error: 7.7948
# Epoch 100/100
# 57/57 [==============================] - 2s 40ms/step - loss: 0.0233 - mean_absolute_percentage_error: 7.1293

# %%
model_45 = Sequential()
model_45.add(LSTM(units=100, return_sequences=True, input_shape=(features_set_45.shape[1], 1)))
model_45.add(Dropout(0.2))
model_45.add(LSTM(units=100, return_sequences=True))
model_45.add(Dropout(0.2))
model_45.add(LSTM(units=200, return_sequences=True))
model_45.add(Dropout(0.2))
model_45.add(LSTM(units=400, return_sequences=True))
model_45.add(Dropout(0.25))
model_45.add(LSTM(units=400, return_sequences=True))
model_45.add(Dropout(0.25))
model_45.add(LSTM(units=200, return_sequences=True))
model_45.add(Dropout(0.2))
model_45.add(LSTM(units=100, return_sequences=True))
model_45.add(Dropout(0.2))
model_45.add(LSTM(units=50))
model_45.add(Dropout(0.2))
model_45.add(Dense(units = 1))

# %%
model_45.compile(optimizer = 'adamax', loss = 'mae', metrics = [tf.keras.metrics.MeanAbsolutePercentageError()])
model_45.fit(features_set_45, labels_45, epochs = 110, batch_size = 32)
# Out:
# Epoch 1/110
# 57/57 [==============================] - 2s 36ms/step - loss: 0.0784 - mean_absolute_percentage_error: 22.7296
# Epoch 2/110
# 57/57 [==============================] - 2s 33ms/step - loss: 0.0580 - mean_absolute_percentage_error: 15.9108
# Epoch 3/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0523 - mean_absolute_percentage_error: 14.8965
# Epoch 4/110
# 57/57 [==============================] - 2s 33ms/step - loss: 0.0498 - mean_absolute_percentage_error: 14.0499
# Epoch 5/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0502 - mean_absolute_percentage_error: 14.2421
# Epoch 6/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0441 - mean_absolute_percentage_error: 12.2745
# Epoch 7/110
# 57/57 [==============================] - 2s 34ms/step - loss: 0.0462 - mean_absolute_percentage_error: 12.5930
# Epoch 8/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0407 - mean_absolute_percentage_error: 11.9241
# Epoch 9/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0416 - mean_absolute_percentage_error: 11.5891
# Epoch 10/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0389 - mean_absolute_percentage_error: 10.8727
# Epoch 11/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0431 - mean_absolute_percentage_error: 12.1819
# Epoch 12/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0402 - mean_absolute_percentage_error: 12.1142
# Epoch 13/110
# 57/57 [==============================] - 2s 33ms/step - loss: 0.0408 - mean_absolute_percentage_error: 12.8825
# Epoch 14/110
# 57/57 [==============================] - 2s 34ms/step - loss: 0.0389 - mean_absolute_percentage_error: 11.3857
# Epoch 15/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0370 - mean_absolute_percentage_error: 10.7664
# Epoch 16/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0403 - mean_absolute_percentage_error: 12.5833
# Epoch 17/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0424 - mean_absolute_percentage_error: 13.3616
# Epoch 18/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0373 - mean_absolute_percentage_error: 11.0565
# Epoch 19/110
# 57/57 [==============================] - 2s 33ms/step - loss: 0.0365 - mean_absolute_percentage_error: 10.7237
# Epoch 20/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0409 - mean_absolute_percentage_error: 12.4556
# Epoch 21/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0368 - mean_absolute_percentage_error: 11.5034
# Epoch 22/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0349 - mean_absolute_percentage_error: 11.0966
# Epoch 23/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0370 - mean_absolute_percentage_error: 12.0064
# Epoch 24/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0356 - mean_absolute_percentage_error: 10.5931
# Epoch 25/110
# 57/57 [==============================] - 2s 33ms/step - loss: 0.0350 - mean_absolute_percentage_error: 10.3547
# Epoch 26/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0356 - mean_absolute_percentage_error: 10.4142
# Epoch 27/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0365 - mean_absolute_percentage_error: 11.8569
# Epoch 28/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0350 - mean_absolute_percentage_error: 10.9624
# Epoch 29/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0343 - mean_absolute_percentage_error: 10.4135
# Epoch 30/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0340 - mean_absolute_percentage_error: 10.3759
# Epoch 31/110
# 57/57 [==============================] - 2s 39ms/step - loss: 0.0389 - mean_absolute_percentage_error: 12.7690
# Epoch 32/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0390 - mean_absolute_percentage_error: 12.0825
# Epoch 33/110
# 57/57 [==============================] - 2s 36ms/step - loss: 0.0312 - mean_absolute_percentage_error: 9.7726
# Epoch 34/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0329 - mean_absolute_percentage_error: 9.7353
# Epoch 35/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0327 - mean_absolute_percentage_error: 10.3118
# Epoch 36/110
# 57/57 [==============================] - 2s 33ms/step - loss: 0.0344 - mean_absolute_percentage_error: 10.5448
# Epoch 37/110
# 57/57 [==============================] - 2s 34ms/step - loss: 0.0309 - mean_absolute_percentage_error: 9.9185
# Epoch 38/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0311 - mean_absolute_percentage_error: 9.2806
# Epoch 39/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0313 - mean_absolute_percentage_error: 9.4983
# Epoch 40/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0320 - mean_absolute_percentage_error: 10.0225
# Epoch 41/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0316 - mean_absolute_percentage_error: 9.9410
# Epoch 42/110
# 57/57 [==============================] - 2s 33ms/step - loss: 0.0293 - mean_absolute_percentage_error: 9.2577
# Epoch 43/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0296 - mean_absolute_percentage_error: 9.2197
# Epoch 44/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0305 - mean_absolute_percentage_error: 9.5571
# Epoch 45/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0307 - mean_absolute_percentage_error: 10.6667
# Epoch 46/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0302 - mean_absolute_percentage_error: 9.0680
# Epoch 47/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0299 - mean_absolute_percentage_error: 9.1323
# Epoch 48/110
# 57/57 [==============================] - 2s 35ms/step - loss: 0.0298 - mean_absolute_percentage_error: 9.8491
# Epoch 49/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0293 - mean_absolute_percentage_error: 9.2879
# Epoch 50/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0299 - mean_absolute_percentage_error: 9.6581
# Epoch 51/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0290 - mean_absolute_percentage_error: 9.2496
# Epoch 52/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0327 - mean_absolute_percentage_error: 10.3734
# Epoch 53/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0285 - mean_absolute_percentage_error: 8.9120
# Epoch 54/110
# 57/57 [==============================] - 2s 33ms/step - loss: 0.0297 - mean_absolute_percentage_error: 9.3323
# Epoch 55/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0290 - mean_absolute_percentage_error: 8.9571
# Epoch 56/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0277 - mean_absolute_percentage_error: 8.9068
# Epoch 57/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0297 - mean_absolute_percentage_error: 9.8594
# Epoch 58/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0291 - mean_absolute_percentage_error: 9.3263
# Epoch 59/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0280 - mean_absolute_percentage_error: 9.1856
# Epoch 60/110
# 57/57 [==============================] - 2s 33ms/step - loss: 0.0278 - mean_absolute_percentage_error: 8.8284
# Epoch 61/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0270 - mean_absolute_percentage_error: 8.9102
# Epoch 62/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0264 - mean_absolute_percentage_error: 8.5067
# Epoch 63/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0267 - mean_absolute_percentage_error: 8.3553
# Epoch 64/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0268 - mean_absolute_percentage_error: 8.8797
# Epoch 65/110
# 57/57 [==============================] - 2s 42ms/step - loss: 0.0286 - mean_absolute_percentage_error: 9.4689
# Epoch 66/110
# 57/57 [==============================] - 2s 34ms/step - loss: 0.0251 - mean_absolute_percentage_error: 8.0035
# Epoch 67/110
# 57/57 [==============================] - 2s 34ms/step - loss: 0.0277 - mean_absolute_percentage_error: 9.3680
# Epoch 68/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0263 - mean_absolute_percentage_error: 9.0237
# Epoch 69/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0274 - mean_absolute_percentage_error: 8.7886
# Epoch 70/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0254 - mean_absolute_percentage_error: 8.3345
# Epoch 71/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0262 - mean_absolute_percentage_error: 9.2940
# Epoch 72/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0257 - mean_absolute_percentage_error: 8.6223
# Epoch 73/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0258 - mean_absolute_percentage_error: 8.9159
# Epoch 74/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0253 - mean_absolute_percentage_error: 8.3284
# Epoch 75/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0262 - mean_absolute_percentage_error: 9.4696
# Epoch 76/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0253 - mean_absolute_percentage_error: 8.0623
# Epoch 77/110
# 57/57 [==============================] - 2s 33ms/step - loss: 0.0249 - mean_absolute_percentage_error: 8.0476
# Epoch 78/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0259 - mean_absolute_percentage_error: 8.2115
# Epoch 79/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0255 - mean_absolute_percentage_error: 8.6906
# Epoch 80/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0242 - mean_absolute_percentage_error: 7.8587
# Epoch 81/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0263 - mean_absolute_percentage_error: 9.0483
# Epoch 82/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0249 - mean_absolute_percentage_error: 7.9325
# Epoch 83/110
# 57/57 [==============================] - 2s 34ms/step - loss: 0.0252 - mean_absolute_percentage_error: 8.2758
# Epoch 84/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0247 - mean_absolute_percentage_error: 8.4463
# Epoch 85/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0250 - mean_absolute_percentage_error: 8.6528
# Epoch 86/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0240 - mean_absolute_percentage_error: 8.1369
# Epoch 87/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0256 - mean_absolute_percentage_error: 8.4310
# Epoch 88/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0250 - mean_absolute_percentage_error: 7.9974
# Epoch 89/110
# 57/57 [==============================] - 2s 33ms/step - loss: 0.0246 - mean_absolute_percentage_error: 8.0804
# Epoch 90/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0262 - mean_absolute_percentage_error: 8.9093
# Epoch 91/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0236 - mean_absolute_percentage_error: 7.6352
# Epoch 92/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0244 - mean_absolute_percentage_error: 7.8244
# Epoch 93/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0247 - mean_absolute_percentage_error: 8.1328
# Epoch 94/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0254 - mean_absolute_percentage_error: 8.6147
# Epoch 95/110
# 57/57 [==============================] - 2s 33ms/step - loss: 0.0227 - mean_absolute_percentage_error: 7.4590
# Epoch 96/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0234 - mean_absolute_percentage_error: 8.1080
# Epoch 97/110
# 57/57 [==============================] - 2s 36ms/step - loss: 0.0223 - mean_absolute_percentage_error: 7.3953
# Epoch 98/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0240 - mean_absolute_percentage_error: 7.9884
# Epoch 99/110
# 57/57 [==============================] - 2s 33ms/step - loss: 0.0240 - mean_absolute_percentage_error: 8.0559
# Epoch 100/110
# 57/57 [==============================] - 2s 36ms/step - loss: 0.0231 - mean_absolute_percentage_error: 7.7622
# Epoch 101/110
# 57/57 [==============================] - 2s 34ms/step - loss: 0.0238 - mean_absolute_percentage_error: 7.9489
# Epoch 102/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0227 - mean_absolute_percentage_error: 8.2573
# Epoch 103/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0249 - mean_absolute_percentage_error: 9.2616
# Epoch 104/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0247 - mean_absolute_percentage_error: 7.7591
# Epoch 105/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0227 - mean_absolute_percentage_error: 7.6568
# Epoch 106/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0234 - mean_absolute_percentage_error: 7.8725
# Epoch 107/110
# 57/57 [==============================] - 2s 33ms/step - loss: 0.0221 - mean_absolute_percentage_error: 7.4819
# Epoch 108/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0231 - mean_absolute_percentage_error: 8.0016
# Epoch 109/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0227 - mean_absolute_percentage_error: 7.7744
# Epoch 110/110
# 57/57 [==============================] - 2s 32ms/step - loss: 0.0237 - mean_absolute_percentage_error: 8.0757

# %%
model_70 = Sequential()
model_70.add(LSTM(units=100, return_sequences=True, input_shape=(features_set_70.shape[1], 1)))
model_70.add(Dropout(0.2))
model_70.add(LSTM(units=100, return_sequences=True))
model_70.add(Dropout(0.2))
model_70.add(LSTM(units=200, return_sequences=True))
model_70.add(Dropout(0.2))
model_70.add(LSTM(units=400, return_sequences=True))
model_70.add(Dropout(0.25))
model_70.add(LSTM(units=400, return_sequences=True))
model_70.add(Dropout(0.25))
model_70.add(LSTM(units=200, return_sequences=True))
model_70.add(Dropout(0.2))
model_70.add(LSTM(units=100, return_sequences=True))
model_70.add(Dropout(0.2))
model_70.add(LSTM(units=100, return_sequences=True))
model_70.add(Dropout(0.2))
model_70.add(LSTM(units=100, return_sequences=True))
model_70.add(Dropout(0.2))
model_70.add(LSTM(units=50))
model_70.add(Dropout(0.2))
model_70.add(Dense(units = 1))

# %%
model_70.compile(optimizer = 'adam', loss = 'mae', metrics = [tf.keras.metrics.MeanAbsolutePercentageError()])
model_70.fit(features_set_70, labels_70, epochs = 110, batch_size = 32)
# Out:
# Epoch 1/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.1107 - mean_absolute_percentage_error: 30.6677
# Epoch 2/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0652 - mean_absolute_percentage_error: 19.4422
# Epoch 3/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0582 - mean_absolute_percentage_error: 17.5555
# Epoch 4/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0546 - mean_absolute_percentage_error: 15.4141
# Epoch 5/110
# 56/56 [==============================] - 3s 55ms/step - loss: 0.0539 - mean_absolute_percentage_error: 15.6761
# Epoch 6/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0542 - mean_absolute_percentage_error: 17.4350
# Epoch 7/110
# 56/56 [==============================] - 3s 58ms/step - loss: 0.0502 - mean_absolute_percentage_error: 14.8380
# Epoch 8/110
# 56/56 [==============================] - 3s 57ms/step - loss: 0.0491 - mean_absolute_percentage_error: 14.8423
# Epoch 9/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0462 - mean_absolute_percentage_error: 13.5173
# Epoch 10/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0430 - mean_absolute_percentage_error: 13.5502
# Epoch 11/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0415 - mean_absolute_percentage_error: 11.5947
# Epoch 12/110
# 56/56 [==============================] - 3s 55ms/step - loss: 0.0395 - mean_absolute_percentage_error: 11.8730
# Epoch 13/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0458 - mean_absolute_percentage_error: 13.6475
# Epoch 14/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0387 - mean_absolute_percentage_error: 11.2827
# Epoch 15/110
# 56/56 [==============================] - 3s 55ms/step - loss: 0.0390 - mean_absolute_percentage_error: 11.5897
# Epoch 16/110
# 56/56 [==============================] - 3s 55ms/step - loss: 0.0381 - mean_absolute_percentage_error: 11.7923
# Epoch 17/110
# 56/56 [==============================] - 3s 55ms/step - loss: 0.0391 - mean_absolute_percentage_error: 11.8044
# Epoch 18/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0380 - mean_absolute_percentage_error: 11.8783
# Epoch 19/110
# 56/56 [==============================] - 3s 55ms/step - loss: 0.0338 - mean_absolute_percentage_error: 10.2469
# Epoch 20/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0390 - mean_absolute_percentage_error: 11.4803
# Epoch 21/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0333 - mean_absolute_percentage_error: 10.2243
# Epoch 22/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0383 - mean_absolute_percentage_error: 12.8521
# Epoch 23/110
# 56/56 [==============================] - 3s 55ms/step - loss: 0.0325 - mean_absolute_percentage_error: 9.7376
# Epoch 24/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0343 - mean_absolute_percentage_error: 10.0139
# Epoch 25/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0343 - mean_absolute_percentage_error: 10.9912
# Epoch 26/110
# 56/56 [==============================] - 3s 58ms/step - loss: 0.0306 - mean_absolute_percentage_error: 9.3335
# Epoch 27/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0319 - mean_absolute_percentage_error: 9.9335
# Epoch 28/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0344 - mean_absolute_percentage_error: 10.2438
# Epoch 29/110
# 56/56 [==============================] - 3s 57ms/step - loss: 0.0306 - mean_absolute_percentage_error: 9.1799
# Epoch 30/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0317 - mean_absolute_percentage_error: 9.4449
# Epoch 31/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0295 - mean_absolute_percentage_error: 9.1747
# Epoch 32/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0292 - mean_absolute_percentage_error: 9.0988
# Epoch 33/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0279 - mean_absolute_percentage_error: 8.2956
# Epoch 34/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0312 - mean_absolute_percentage_error: 9.2695
# Epoch 35/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0287 - mean_absolute_percentage_error: 8.6107
# Epoch 36/110
# 56/56 [==============================] - 3s 55ms/step - loss: 0.0275 - mean_absolute_percentage_error: 8.2190
# Epoch 37/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0296 - mean_absolute_percentage_error: 9.5536
# Epoch 38/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0282 - mean_absolute_percentage_error: 8.4633
# Epoch 39/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0278 - mean_absolute_percentage_error: 8.3067
# Epoch 40/110
# 56/56 [==============================] - 3s 55ms/step - loss: 0.0299 - mean_absolute_percentage_error: 9.3826
# Epoch 41/110
# 56/56 [==============================] - 3s 55ms/step - loss: 0.0274 - mean_absolute_percentage_error: 8.7960
# Epoch 42/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0284 - mean_absolute_percentage_error: 8.7772
# Epoch 43/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0277 - mean_absolute_percentage_error: 8.5705
# Epoch 44/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0265 - mean_absolute_percentage_error: 8.1588
# Epoch 45/110
# 56/56 [==============================] - 3s 57ms/step - loss: 0.0260 - mean_absolute_percentage_error: 8.0009
# Epoch 46/110
# 56/56 [==============================] - 3s 57ms/step - loss: 0.0276 - mean_absolute_percentage_error: 8.7864
# Epoch 47/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0280 - mean_absolute_percentage_error: 9.0420
# Epoch 48/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0258 - mean_absolute_percentage_error: 8.2173
# Epoch 49/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0258 - mean_absolute_percentage_error: 7.8987
# Epoch 50/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0274 - mean_absolute_percentage_error: 8.6136
# Epoch 51/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0256 - mean_absolute_percentage_error: 8.3927
# Epoch 52/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0250 - mean_absolute_percentage_error: 8.1220
# Epoch 53/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0265 - mean_absolute_percentage_error: 8.4153
# Epoch 54/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0289 - mean_absolute_percentage_error: 8.7116
# Epoch 55/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0252 - mean_absolute_percentage_error: 7.8108
# Epoch 56/110
# 56/56 [==============================] - 3s 55ms/step - loss: 0.0261 - mean_absolute_percentage_error: 8.4023
# Epoch 57/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0237 - mean_absolute_percentage_error: 7.5597
# Epoch 58/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0276 - mean_absolute_percentage_error: 9.6848
# Epoch 59/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0238 - mean_absolute_percentage_error: 7.3504
# Epoch 60/110
# 56/56 [==============================] - 3s 55ms/step - loss: 0.0276 - mean_absolute_percentage_error: 8.6268
# Epoch 61/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0241 - mean_absolute_percentage_error: 7.6848
# Epoch 62/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0235 - mean_absolute_percentage_error: 7.4987
# Epoch 63/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0242 - mean_absolute_percentage_error: 7.8057
# Epoch 64/110
# 56/56 [==============================] - 3s 58ms/step - loss: 0.0270 - mean_absolute_percentage_error: 8.9195
# Epoch 65/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0247 - mean_absolute_percentage_error: 8.5036
# Epoch 66/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0264 - mean_absolute_percentage_error: 8.7124
# Epoch 67/110
# 56/56 [==============================] - 3s 57ms/step - loss: 0.0243 - mean_absolute_percentage_error: 7.9280
# Epoch 68/110
# 56/56 [==============================] - 3s 55ms/step - loss: 0.0244 - mean_absolute_percentage_error: 7.8512
# Epoch 69/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0230 - mean_absolute_percentage_error: 7.7066
# Epoch 70/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0231 - mean_absolute_percentage_error: 7.1672
# Epoch 71/110
# 56/56 [==============================] - 3s 55ms/step - loss: 0.0226 - mean_absolute_percentage_error: 7.3046
# Epoch 72/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0223 - mean_absolute_percentage_error: 7.4326
# Epoch 73/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0231 - mean_absolute_percentage_error: 7.5151
# Epoch 74/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0234 - mean_absolute_percentage_error: 7.7256
# Epoch 75/110
# 56/56 [==============================] - 3s 55ms/step - loss: 0.0228 - mean_absolute_percentage_error: 7.4509
# Epoch 76/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0236 - mean_absolute_percentage_error: 8.0244
# Epoch 77/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0231 - mean_absolute_percentage_error: 7.7855
# Epoch 78/110
# 56/56 [==============================] - 3s 55ms/step - loss: 0.0222 - mean_absolute_percentage_error: 7.0675
# Epoch 79/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0237 - mean_absolute_percentage_error: 7.5496
# Epoch 80/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0220 - mean_absolute_percentage_error: 7.3366
# Epoch 81/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0223 - mean_absolute_percentage_error: 7.7541
# Epoch 82/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0211 - mean_absolute_percentage_error: 6.9332
# Epoch 83/110
# 56/56 [==============================] - 3s 58ms/step - loss: 0.0231 - mean_absolute_percentage_error: 7.4414
# Epoch 84/110
# 56/56 [==============================] - 3s 57ms/step - loss: 0.0235 - mean_absolute_percentage_error: 7.6707
# Epoch 85/110
# 56/56 [==============================] - 3s 57ms/step - loss: 0.0225 - mean_absolute_percentage_error: 7.3076
# Epoch 86/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0231 - mean_absolute_percentage_error: 7.8586
# Epoch 87/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0237 - mean_absolute_percentage_error: 7.8899
# Epoch 88/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0242 - mean_absolute_percentage_error: 8.1132
# Epoch 89/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0227 - mean_absolute_percentage_error: 7.2601
# Epoch 90/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0234 - mean_absolute_percentage_error: 8.0523
# Epoch 91/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0209 - mean_absolute_percentage_error: 6.9506
# Epoch 92/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0235 - mean_absolute_percentage_error: 7.9345
# Epoch 93/110
# 56/56 [==============================] - 3s 55ms/step - loss: 0.0217 - mean_absolute_percentage_error: 7.6464
# Epoch 94/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0223 - mean_absolute_percentage_error: 7.9303
# Epoch 95/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0207 - mean_absolute_percentage_error: 6.6045
# Epoch 96/110
# 56/56 [==============================] - 3s 55ms/step - loss: 0.0225 - mean_absolute_percentage_error: 7.8251
# Epoch 97/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0235 - mean_absolute_percentage_error: 7.6683
# Epoch 98/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0199 - mean_absolute_percentage_error: 6.6500
# Epoch 99/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0220 - mean_absolute_percentage_error: 7.5588
# Epoch 100/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0231 - mean_absolute_percentage_error: 7.7979
# Epoch 101/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0219 - mean_absolute_percentage_error: 7.4617
# Epoch 102/110
# 56/56 [==============================] - 3s 60ms/step - loss: 0.0231 - mean_absolute_percentage_error: 7.5151
# Epoch 103/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0225 - mean_absolute_percentage_error: 7.6508
# Epoch 104/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0206 - mean_absolute_percentage_error: 7.0352
# Epoch 105/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0239 - mean_absolute_percentage_error: 8.6478
# Epoch 106/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0242 - mean_absolute_percentage_error: 8.4202
# Epoch 107/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0219 - mean_absolute_percentage_error: 7.5272
# Epoch 108/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0216 - mean_absolute_percentage_error: 7.3249
# Epoch 109/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0214 - mean_absolute_percentage_error: 7.6254
# Epoch 110/110
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0208 - mean_absolute_percentage_error: 7.1327

# %% [markdown]
# **Now, test the model again real world data from Nov 10, 2017 (where our train data ends) and forecast a couple months**

# %%
tsla_testing = pd.read_csv('../input/aapl-test/AAPL (2).csv')
tsla_testing.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2017-11-09  43.777500  44.025002  43.285000  43.970001  42.161411
# 1  2017-11-10  43.777500  43.845001  43.567501  43.667500  42.021866
# 2  2017-11-13  43.375000  43.625000  43.349998  43.492500  41.853470
# 3  2017-11-14  43.259998  43.369999  42.794998  42.834999  41.220745
# 4  2017-11-15  42.492500  42.580002  42.095001  42.270000  40.677040
#
#       Volume
# 0  117930400
# 1  100582000
# 2   67928400
# 3   99130000
# 4  116632400

# %%
tsla_testing.plot(x="Date", y=["Open"])

# %%
tsla_testing["High-Low"]=tsla_testing["High"] - tsla_testing["Low"]
tsla_testing.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2017-11-09  43.777500  44.025002  43.285000  43.970001  42.161411
# 1  2017-11-10  43.777500  43.845001  43.567501  43.667500  42.021866
# 2  2017-11-13  43.375000  43.625000  43.349998  43.492500  41.853470
# 3  2017-11-14  43.259998  43.369999  42.794998  42.834999  41.220745
# 4  2017-11-15  42.492500  42.580002  42.095001  42.270000  40.677040
#
#       Volume  High-Low
# 0  117930400  0.740002
# 1  100582000  0.277500
# 2   67928400  0.275002
# 3   99130000  0.575001
# 4  116632400  0.485001

# %%
df_test = tsla_testing[['Open']]

# %% [markdown]
# **Concatenate both the training and test datasets**

# %%
df_total = pd.concat((df_tsla[['Open']], df_test[['Open']]), axis=0)
df_total.tail()
# Out:
#          Open
# 76  43.200001
# 77  43.802502
# 78  44.477501
# 79  43.735001
# 80  43.869999

# %%
len(df_total)
# Out:
# 1936

# %%
len(df_test)
# Out:
# 81

# %%
df_test[['Open']]
# Out:
#          Open
# 0   43.777500
# 1   43.777500
# 2   43.375000
# 3   43.259998
# 4   42.492500
# ..        ...
# 76  43.200001
# 77  43.802502
# 78  44.477501
# 79  43.735001
# 80  43.869999
#
# [81 rows x 1 columns]

# %% [markdown]
# **Test different timesteps**

# %% [markdown]
# For timestep 60:

# %%
test_inputs = df_total[len(df_total) - len(df_test) - 60:].values

# %%
test_inputs[:10]
# Out:
# array([[40.485001],
#        [40.130001],
#        [39.465   ],
#        [39.375   ],
#        [39.557499],
#        [39.767502],
#        [40.107498],
#        [39.912498],
#        [40.035   ],
#        [40.025002]])

# %%
scaler = MinMaxScaler(feature_range = (-1, 1))
test_inputs = scaler.fit_transform(test_inputs)

# %%
test_inputs[:10]
# Out:
# array([[-0.18652122],
#        [-0.28318565],
#        [-0.46426153],
#        [-0.488768  ],
#        [-0.43907459],
#        [-0.381892  ],
#        [-0.28931308],
#        [-0.34241044],
#        [-0.30905386],
#        [-0.31177626]])

# %%
test_features = []
for i in range(60, 81):
    test_features.append(test_inputs[i-60:i, 0])

# %%
test_features = np.array(test_features)
test_features = np.reshape(test_features, (test_features.shape[0], test_features.shape[1], 1))

# %%
test_features.shape
# Out:
# (21, 60, 1)

# %%
predictions = model.predict(test_features)
predictions = scaler.inverse_transform(predictions)

# %%
predictions.shape
# Out:
# (21, 1)

# %%
predictions[:10]
# Out:
# array([[43.40992 ],
#        [43.688347],
#        [43.86218 ],
#        [43.900703],
#        [43.79324 ],
#        [43.53025 ],
#        [43.17995 ],
#        [42.881313],
#        [42.72587 ],
#        [42.698757]], dtype=float32)

# %%
plt.figure(figsize=(10,10))
plt.plot((df_test[['Open']])[:21], color='blue', label='Actual AAPL Stock Price')
plt.plot(predictions, color='red', label='Predicted AAPL Stock Price')
plt.title('AAPL Stock Price Prediction')
plt.xlabel('Date')
plt.ylabel('AAPL Stock Price')
plt.legend()
plt.show()

# %%
test_features_45 = []
for i in range(45, 81):
    test_features_45.append(test_inputs[i-45:i, 0])

# %%
test_features_45 = np.array(test_features_45)
test_features_45 = np.reshape(test_features_45, (test_features_45.shape[0], test_features_45.shape[1], 1))

# %%
predictions_45 = model_45.predict(test_features_45)
# create empty table with 3 fields
testPredict_dataset_like = np.zeros(shape=(len(predictions_45), 3) )
# put the predicted values in the right field
testPredict_dataset_like[:,0] = predictions_45[:,0]
# inverse transform and then select the right field
testPredict = scaler.inverse_transform(testPredict_dataset_like)[:,0]
predictions_45 = testPredict
plt.figure(figsize=(10,6))
plt.plot((df_test[['Open']])[:36], color='blue', label='Actual AAPL Stock Price')
plt.plot(predictions_45, color='red', label='Predicted AAPL Stock Price')
plt.title('AAPL Stock Price Prediction')
plt.xlabel('Date')
plt.ylabel('AAPL Stock Price')
plt.legend()
plt.show()

# %%
test_features_70 = []
for i in range(70, 81):
    test_features_70.append(test_inputs[i-70:i, 0])

# %%
test_features_70 = np.array(test_features_70)
test_features_70 = np.reshape(test_features_70, (test_features_70.shape[0], test_features_70.shape[1], 1))

# %%
predictions_70 = model_70.predict(test_features_70)
# create empty table with 3 fields
testPredict_dataset_like = np.zeros(shape=(len(predictions_70), 3) )
# put the predicted values in the right field
testPredict_dataset_like[:,0] = predictions_70[:,0]
# inverse transform and then select the right field
testPredict = scaler.inverse_transform(testPredict_dataset_like)[:,0]
predictions_70 = testPredict
plt.figure(figsize=(10,6))
plt.plot((df_test[['Open']])[:11], color='blue', label='Actual AAPL Stock Price')
plt.plot(predictions_70, color='red', label='Predicted AAPL Stock Price')
plt.title('AAPL Stock Price Prediction')
plt.xlabel('Date')
plt.ylabel('AAPL Stock Price')
plt.legend()
plt.show()
